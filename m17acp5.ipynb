# %% [markdown]
# **Hot and cold**

# %%
temp=int(input("Enter temperature in celsius"))
if (temp< 15):
 print("Cold" )
elif (15 <= temp<= 25):
  print ("Warm")
else:
 print("Hot")
# Out:
# Enter temperature in celsius 40
# Hot
